# %%
# !git clone https://github.com/enkeejunior1/Diffusion-Pullback.git
# !pip install -r /content/Diffusion-Pullback/requirements.txt

# %%
# %ls
# Out:
# example-code.ipynb  LICENSE    requirements_colab.txt  src/
# figures/            README.md  requirements.txt

# %%
# %cd src/
# !bash scripts/main_various_local_encoder_pullback_with_edit_prompt_3.sh
# Out:
# device : cuda:0, dtype : torch.float32
# is stable-diffusion
# Fetching 13 files: 100%|████████████████████| 13/13 [00:00<00:00, 183589.06it/s]
# current experiment : idx : 5, op : mid, block_idx : 0, vis_num : 4, vis_num_pc : 2, pca_rank : 2, edit_prompt : chihuahua
# start DDIMinversion
# start DDIMforward
# do_classifier_free_guidance :  False
# self.neg_prompt :
# self.for_prompt :
# t_start_idx :  0
# t_end_idx :  30
# !!!RUN LOCAL PULLBACK!!!
# power method : 0-th step convergence :  1.932939052581787
# power method : 1-th step convergence :  0.7428337931632996
# power method : 2-th step convergence :  0.4135113060474396
# power method : 3-th step convergence :  0.254056841135025
# power method : 4-th step convergence :  0.1466841697692871
# power method : 5-th step convergence :  0.09703854471445084
# power method : 6-th step convergence :  0.07642456144094467
# power method : 7-th step convergence :  0.06702885031700134
# ...

# %%
# !nvidia-smi
# Out:
# Wed Apr  3 01:04:01 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.154.05             Driver Version: 535.154.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-PCIE-32GB           On  | 00000000:D8:00.0 Off |                  Off |
# | N/A   34C    P0              34W / 250W |  16006MiB / 32768MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !bash scripts/main_various_local_encoder_pullback_with_edit_prompt.sh
# Out:
# device : cuda:0, dtype : torch.float32
# is stable-diffusion
# model_index.json: 100%|████████████████████████| 543/543 [00:00<00:00, 4.90MB/s]
# text_encoder/pytorch_model.fp16.safetensors not found
# Fetching 22 files:   0%|                                 | 0/22 [00:00<?, ?it/s]
# text_encoder/model.safetensors:   0%|               | 0.00/1.36G [00:00<?, ?B/s]
#
# text_encoder/pytorch_model.bin:   0%|               | 0.00/1.36G [00:00<?, ?B/s]
#
#
# scheduler/scheduler_config.json: 100%|█████████| 346/346 [00:00<00:00, 4.27MB/s]
#
#
#
# (…)ature_extractor/preprocessor_config.json: 100%|█| 342/342 [00:00<00:00, 4.63M
# Fetching 22 files:   5%|█▏                       | 1/22 [00:00<00:05,  4.03it/s]
#
#
# tokenizer/merges.txt:   0%|                          | 0.00/525k [00:00<?, ?B/s]
# text_encoder/model.safetensors:   1%|      | 10.5M/1.36G [00:00<00:21, 61.7MB/s]
#
# text_encoder/pytorch_model.bin:   1%|      | 10.5M/1.36G [00:00<00:21, 61.4MB/s]
#
#
#
# ...
